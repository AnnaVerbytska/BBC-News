# %%
# Import the libraries
import pandas as pd
from google.cloud import bigquery #pip install google-cloud-bigquery for SQL

# %%
project='bbc-news-432613' #Put your project id

# %%
# Initialize a BigQuery Client
client=bigquery.Client(project)

# Construct a reference to a dataset 
dataset_ref=client.dataset('bbc_news', project='bigquery-public-data')

# Fetch the dataset
dataset=client.get_dataset(dataset_ref)

# Construct the reference to a table
table_ref=dataset_ref.table('fulltext')

# Get info on the columns
table=client.get_table(table_ref)

# Put the table to a DataFrame and preview
df = client.list_rows(table).to_dataframe()
# Out:
# /Users/anna_verbytska/Documents/BBC-News/.venv/lib/python3.12/site-packages/google/cloud/bigquery/table.py:1727: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(

# %%
df.tail(20)
# Out:
#                                                    body  \
# 2205  Pop star Britney Spears has attacked "false" a...
# 2206  The man who said he got Oscar-nominated movie ...
# 2207  The top names in Scottish music are taking par...
# 2208  Fans who buy tickets for this year's Glastonbu...
# 2209  Rock star Ozzy Osbourne has been praised by po...
# 2210  Former England footballer Paul Gascoigne will ...
# 2211  Germaine Greer has criticised Celebrity Big Br...
# 2212  A bookmaker has stopped taking bets on Celebri...
# 2213  Pop singer Delta Goodrem has scooped one of th...
# 2214  Singer Bruce Springsteen has inducted Irish ro...
# 2215  Film comedy Meet The Fockers, sequel to Meet T...
# 2216  Roxy Music will appear at June's Isle of Wight...
# 2217  Uganda's authorities have banned the play The ...
# 2218  The release of a film about the Mumbai (Bombay...
# 2219  The Aviator has been tipped by UK bookmakers a...
# 2220  Singer Pete Doherty will have to spend the wee...
# 2221  The new version of the Band Aid song Do They K...
# 2222  Ipod owners can now download the Band Aid sing...
# 2223  R&B star Alicia Keys is to open February's Sup...
# 2224  A British Muslim group has criticised the new ...
#
#                                   title                   filename  \
# 2205   Britney attacks 'false tabloids'  bbc/entertainment/345.txt
# 2206   Aviator 'creator' in Oscars snub  bbc/entertainment/039.txt
# 2207  Glasgow hosts tsunami benefit gig  bbc/entertainment/104.txt
# 2208   Glastonbury fans to get ID cards  bbc/entertainment/137.txt
# 2209    Police praise 'courageous' Ozzy  bbc/entertainment/141.txt
# 2210    Celebrities get their skates on  bbc/entertainment/188.txt
# 2211  Greer attacks 'bully' Big Brother  bbc/entertainment/203.txt
# 2212  Bets off after Big Brother 'leak'  bbc/entertainment/221.txt
# 2213  Goodrem wins top female MTV prize  bbc/entertainment/286.txt
# 2214   U2 stars enter rock Hall of Fame  bbc/entertainment/291.txt
# 2215   Fockers keeps US box office lead  bbc/entertainment/297.txt
# 2216   Roxy Music on Isle of Wight bill  bbc/entertainment/318.txt
# 2217      Uganda bans Vagina Monologues  bbc/entertainment/010.txt
# 2218       Mumbai bombs movie postponed  bbc/entertainment/054.txt
# 2219  Bookmakers back Aviator for Oscar  bbc/entertainment/086.txt
# 2220  Pete Doherty misses bail deadline  bbc/entertainment/114.txt
# 2221  Band Aid 20 single storms to No 1  bbc/entertainment/159.txt
# 2222   iTunes now selling Band Aid song  bbc/entertainment/160.txt
# 2223  Alicia Keys to open US Super Bowl  bbc/entertainment/175.txt
# 2224   Muslim group attacks TV drama 24  bbc/entertainment/210.txt
#
#            category
# 2205  entertainment
# 2206  entertainment
# 2207  entertainment
# 2208  entertainment
# 2209  entertainment
# 2210  entertainment
# 2211  entertainment
# 2212  entertainment
# 2213  entertainment
# 2214  entertainment
# 2215  entertainment
# 2216  entertainment
# 2217  entertainment
# 2218  entertainment
# 2219  entertainment
# 2220  entertainment
# 2221  entertainment
# 2222  entertainment
# 2223  entertainment
# 2224  entertainment

# %%
# import transformer libraries
from transformers import pipeline
#Import the libraries
import flair
import ast
import torch

# %%
#Initialize the model for Sentiment analysis
model = flair.models.TextClassifier.load('en-sentiment')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[23], line 2
#       1 #Initialize the model for Sentiment analysis
# ----> 2 model = flair.models.TextClassifier.load('en-sentiment')
#
# File ~/Documents/BBC-News/.venv/lib/python3.12/site-packages/flair/models/text_classification_model.py:139, in TextClassifier.load(cls, model_path)
#     135 @classmethod
#     136 def load(cls, model_path: Union[str, Path, Dict[str, Any]]) -> "TextClassifier":
#     137     from typing import cast
# --> 139     return cast("TextClassifier", super().load(model_path=model_path))
#
# File ~/Documents/BBC-News/.venv/lib/python3.12/site-packages/flair/nn/model.py:989, in DefaultClassifier.load(cls, model_path)
#     985 @classmethod
#     986 def load(cls, model_path: Union[str, Path, Dict[str, Any]]) -> "DefaultClassifier":
#     987     from typing import cast
# --> 989     return cast("DefaultClassifier", super().load(model_path=model_path))
#
# File ~/Documents/BBC-News/.venv/lib/python3.12/site-packages/flair/nn/model.py:564, in Classifier.load(cls, model_path)
#     560 @classmethod
#     561 def load(cls, model_path: Union[str, Path, Dict[str, Any]]) -> "Classifier":
#     562     from typing import cast
# --> 564     return cast("Classifier", super().load(model_path=model_path))
#
# File ~/Documents/BBC-News/.venv/lib/python3.12/site-packages/flair/nn/model.py:190, in Model.load(cls, model_path)
#     188 if not isinstance(model_path, dict):
#     189     model_file = cls._fetch_model(str(model_path))
# --> 190     state = load_torch_state(model_file)
#     191 else:
#     192     state = model_path
#
# File ~/Documents/BBC-News/.venv/lib/python3.12/site-packages/flair/file_utils.py:384, in load_torch_state(model_file)
#     380 # load_big_file is a workaround byhttps://github.com/highway11git
#     381 # to load models on some Mac/Windows setups
#     382 # see https://github.com/zalandoresearch/flair/issues/351
#     383 f = load_big_file(model_file)
# --> 384 return torch.load(f, map_location="cpu")
#
# File ~/Documents/BBC-News/.venv/lib/python3.12/site-packages/torch/serialization.py:1097, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1095             except RuntimeError as e:
#    1096                 raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
# -> 1097         return _load(
#    1098             opened_zipfile,
#    1099             map_location,
#    1100             pickle_module,
#    1101             overall_storage=overall_storage,
#    1102             **pickle_load_args,
#    1103         )
#    1104 if mmap:
#    1105     f_name = "" if not isinstance(f, str) else f"{f}, "
#
# File ~/Documents/BBC-News/.venv/lib/python3.12/site-packages/torch/serialization.py:1525, in _load(zip_file, map_location, pickle_module, pickle_file, overall_storage, **pickle_load_args)
#    1522 # Needed for tensors where storage device and rebuild tensor device are
#    1523 # not connected (wrapper subclasses and tensors rebuilt using numpy)
#    1524 torch._utils._thread_local_state.map_location = map_location
# -> 1525 result = unpickler.load()
#    1526 del torch._utils._thread_local_state.map_location
#    1528 torch._utils._validate_loaded_sparse_tensors()
#
# File ~/Documents/BBC-News/.venv/lib/python3.12/site-packages/flair/embeddings/transformer.py:1303, in TransformerEmbeddings.__setstate__(self, state)
#    1300     config_class = CONFIG_MAPPING[model_type]
#    1301     config = config_class.from_dict(config_state_dict)
# -> 1303 embedding = self.create_from_state(saved_config=config, **state)
#    1305 # copy values from new embedding
#    1306 for key in embedding.__dict__:
#
# File ~/Documents/BBC-News/.venv/lib/python3.12/site-packages/flair/embeddings/document.py:63, in TransformerDocumentEmbeddings.create_from_state(cls, **state)
#      59 @classmethod
#      60 def create_from_state(cls, **state):
#      61     # this parameter is fixed
#      62     del state["is_document_embedding"]
# ---> 63     return cls(**state)
#
# File ~/Documents/BBC-News/.venv/lib/python3.12/site-packages/flair/embeddings/document.py:49, in TransformerDocumentEmbeddings.__init__(self, model, layers, layer_mean, is_token_embedding, **kwargs)
#      30 def __init__(
#      31     self,
#      32     model: str = "bert-base-uncased",  # set parameters with different default values
#    (...)
#      36     **kwargs,
#      37 ) -> None:
#      38     """Bidirectional transformer embeddings of words from various transformer architectures.
#      39
#      40     Args:
#    (...)
#      47         **kwargs: Arguments propagated to :meth:`flair.embeddings.transformer.TransformerEmbeddings.__init__`
#      48     """
# ---> 49     TransformerEmbeddings.__init__(
#      50         self,
#      51         model=model,
#      52         layers=layers,
#      53         layer_mean=layer_mean,
#      54         is_token_embedding=is_token_embedding,
#      55         is_document_embedding=True,
#      56         **kwargs,
#      57     )
#
# File ~/Documents/BBC-News/.venv/lib/python3.12/site-packages/flair/embeddings/transformer.py:1095, in TransformerEmbeddings.__init__(self, model, fine_tune, layers, layer_mean, subtoken_pooling, cls_pooling, is_token_embedding, is_document_embedding, allow_long_sentences, use_context, respect_document_boundaries, context_dropout, saved_config, tokenizer_data, feature_extractor_data, name, force_max_length, needs_manual_ocr, use_context_separator, transformers_tokenizer_kwargs, transformers_config_kwargs, transformers_model_kwargs, peft_config, peft_gradient_checkpointing_kwargs, **kwargs)
#    1093         transformer_model = T5EncoderModel(saved_config, **transformers_model_kwargs, **kwargs)
#    1094     else:
# -> 1095         transformer_model = AutoModel.from_config(saved_config, **transformers_model_kwargs, **kwargs)
#    1096 try:
#    1097     transformer_model = transformer_model.to(flair.device)
#
# File ~/Documents/BBC-News/.venv/lib/python3.12/site-packages/transformers/utils/import_utils.py:1637, in DummyObject.__getattribute__(cls, key)
#    1635 if key.startswith("_") and key != "_from_config":
#    1636     return super().__getattribute__(key)
# -> 1637 requires_backends(cls, cls._backends)
#
# File ~/Documents/BBC-News/.venv/lib/python3.12/site-packages/transformers/utils/import_utils.py:1625, in requires_backends(obj, backends)
#    1623 failed = [msg.format(name) for available, msg in checks if not available()]
#    1624 if failed:
# -> 1625     raise ImportError("".join(failed))
#
# ImportError:
# AutoModel requires the PyTorch library but it was not found in your environment. Checkout the instructions on the
# installation page: https://pytorch.org/get-started/locally/ and follow the ones that match your environment.
# Please note that you may need to restart your runtime after installation.

# %%
#classifier = pipeline('text-classification')
